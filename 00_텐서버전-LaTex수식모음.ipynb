# %%
# pip install tensorflow==2.13.0
# Out:
# ...
#    ---------------------------------------- 0.0/276.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/276.5 MB ? eta -:--:--
#    ---------------------------------------- 2.6/276.5 MB 8.4 MB/s eta 0:00:33
#     --------------------------------------- 5.2/276.5 MB 10.6 MB/s eta 0:00:26
#    - -------------------------------------- 7.3/276.5 MB 9.8 MB/s eta 0:00:28
#    - -------------------------------------- 10.2/276.5 MB 10.8 MB/s eta 0:00:25
#    - -------------------------------------- 10.2/276.5 MB 10.8 MB/s eta 0:00:25
#    - -------------------------------------- 10.2/276.5 MB 10.8 MB/s eta 0:00:25
#    - -------------------------------------- 10.7/276.5 MB 7.5 MB/s eta 0:00:36
#    - -------------------------------------- 10.7/276.5 MB 7.5 MB/s eta 0:00:36
#    - -------------------------------------- 13.4/276.5 MB 6.5 MB/s eta 0:00:41
#    -- ------------------------------------- 16.0/276.5 MB 7.1 MB/s eta 0:00:37
# ...

# %%
# # conda install -c conda-forge graphviz
# 222p의 의사결정나무 추출전

# %% [markdown]
# $y=2x+1$ <p>
# $a_1$  <p>
# $a_{ij}$  <p>
# $b^2$  <p>
# $b^{ij}$  <p>
# $c_1^2$  <p>
# $y=x^3+2x^2+x+3$  <p>
# $y=\sqrt x$  <p>
# $y=\sin x$  <p>
# $y=\cos x$  <p>
# $y=\frac{3}{4}$  <p>
# $y=\sum_{k=1}^n a_k$  <p>
# $$y=\prod_{k=1}^n a_k$$  <p>

# %% [markdown]
# $$Gini=1-\sum_{}{}_ip^2_i$$

# %% [markdown]
# 계산은 1-[(2/9)$^2$+(4/9)$^2$+(3/9)$^2$]입니다.
